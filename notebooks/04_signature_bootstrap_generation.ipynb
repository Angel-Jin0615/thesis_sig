# %% [markdown]
# # 04 Signature Bootstrap Generation
# Generate synthetic market scenarios with historical bootstrap and signature-conditioned bootstrap.

# %%
# !python src/models/run_signature_bootstrap.py
