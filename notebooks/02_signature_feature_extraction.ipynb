# %% [markdown]
# # 02 Signature Feature Extraction
# Build rolling normalized log-price windows, time-augment paths, compute truncated signatures, and cache outputs.

# %%
# !python src/clustering/build_signature_dataset.py
