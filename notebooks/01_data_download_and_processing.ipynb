# %% [markdown]
# # 01 Data Download and Processing
# Download raw daily equity/FX data from Yahoo Finance and build cleaned processed files with `Date, price, log_price, log_return`.

# %%
# !python src/data/download_data.py

# %%
# !python src/data/process_data.py
